# %%
import numpy as np
import pandas as pd
import sys
sys.path.append('..')
from config import config
from etl.read_files import read_files

# %%
config.inputs_path['calendar']
# Out:
# 'C:\\Users\\Lucas\\Documents\\Lucas\\Ciência de Dados\\kaggle\\M5 Acurracy\\M5ForecastingAccuracy\\data\\calendar.csv'

# %%
calendar, sell_prices, sales_train_validation, sample_submission = read_files()

# %%
sell_prices[0:10]
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26
# 5     CA_1  HOBBIES_1_001     11330        8.26
# 6     CA_1  HOBBIES_1_001     11331        8.26
# 7     CA_1  HOBBIES_1_001     11332        8.26
# 8     CA_1  HOBBIES_1_001     11333        8.26
# 9     CA_1  HOBBIES_1_001     11334        8.26

# %%
calendar.loc[calendar['snap_CA'] == 1]
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# 5     2011-02-03     11101   Thursday     6      2  2011     d_6
# 6     2011-02-04     11101     Friday     7      2  2011     d_7
# 7     2011-02-05     11102   Saturday     1      2  2011     d_8
# 8     2011-02-06     11102     Sunday     2      2  2011     d_9
# 9     2011-02-07     11102     Monday     3      2  2011    d_10
# 10    2011-02-08     11102    Tuesday     4      2  2011    d_11
# 11    2011-02-09     11102  Wednesday     5      2  2011    d_12
# 12    2011-02-10     11102   Thursday     6      2  2011    d_13
# 31    2011-03-01     11105    Tuesday     4      3  2011    d_32
# 32    2011-03-02     11105  Wednesday     5      3  2011    d_33
# 33    2011-03-03     11105   Thursday     6      3  2011    d_34
# ...

# %%
calendar['date'] = pd.to_datetime(calendar.date)
print('primeira data no calendardio: ', min(calendar.date))
print('ultima data no calendardio: ', max(calendar.date))
print('range: ',max(calendar.date) - min(calendar.date))
# Out:
# primeira data no calendardio:  2011-01-29 00:00:00
# ultima data no calendardio:  2016-06-19 00:00:00
# range:  1968 days 00:00:00

# %%
sales_train_validation[0:10]
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
# 5  HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1
# 6  HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1
# 7  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 8  HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1
# 9  HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4   ...    d_1904  d_1905  d_1906  d_1907  \
# ...

# %%
print('id unicos: ', len(sales_train_validation['id'].unique().tolist()))
print('item_id unicos: ', len(sales_train_validation['item_id'].unique().tolist()))
print('dpt_id unicos: ', len(sales_train_validation['dept_id'].unique().tolist()))
print('cat_id unicos: ', len(sales_train_validation['cat_id'].unique().tolist()))
print('store_id unicos: ', len(sales_train_validation['store_id'].unique().tolist()))
print('state_id unicos: ', len(sales_train_validation['state_id'].unique().tolist()))
# Out:
# id unicos:  30490
# item_id unicos:  3049
# dpt_id unicos:  7
# cat_id unicos:  3
# store_id unicos:  10
# state_id unicos:  3

# %%
print('estados: ', sales_train_validation['state_id'].unique().tolist())
print('categorias: ', sales_train_validation['cat_id'].unique().tolist())
print('dptos: ', sales_train_validation['dept_id'].unique().tolist())
print('lojas: ', sales_train_validation['store_id'].unique().tolist())
# Out:
# estados:  ['CA', 'TX', 'WI']
# categorias:  ['HOBBIES', 'HOUSEHOLD', 'FOODS']
# dptos:  ['HOBBIES_1', 'HOBBIES_2', 'HOUSEHOLD_1', 'HOUSEHOLD_2', 'FOODS_1', 'FOODS_2', 'FOODS_3']
# lojas:  ['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1', 'WI_2', 'WI_3']
